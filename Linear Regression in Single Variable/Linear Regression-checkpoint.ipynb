# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('price.csv')

# %%
data
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x=data.area,y=data.price)
# Out:
# <AxesSubplot:xlabel='area', ylabel='price'>

# %%
plt.figure(figsize=(12,6))
sns.regplot(x=data.area,y=data.price,color='red',marker='*')
# Out:
# <AxesSubplot:xlabel='area', ylabel='price'>

# %%
X = data.drop('price',axis=1)

# %%
X
# Out:
#    area
# 0  2600
# 1  3000
# 2  3200
# 3  3600
# 4  4000

# %%
y = data.price

# %%
y
# Out:
# 0    550000
# 1    565000
# 2    610000
# 3    680000
# 4    725000
# Name: price, dtype: int64

# %%
X.shape
# Out:
# (5, 1)

# %%
y.shape
# Out:
# (5,)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X,y)
# Out:
# LinearRegression()

# %%
lr.predict([[3000]])
# Out:
# array([587979.45205479])

# %%
lr.coef_
# Out:
# array([135.78767123])

# %%
lr.intercept_
# Out:
# 180616.43835616432

# %%
area = pd.read_csv('area.csv')

# %%
area
# Out:
#     area
# 0   1000
# 1   1500
# 2   2300
# 3   3540
# 4   4120
# 5   4560
# 6   5490
# 7   3460
# 8   4750
# 9   2300
# 10  9000
# 11  8600
# 12  7100

# %%
area['Predicted Price'] = lr.predict(area)

# %%
area
# Out:
#     area  Predicted Price
# 0   1000     3.164041e+05
# 1   1500     3.842979e+05
# 2   2300     4.929281e+05
# 3   3540     6.613048e+05
# 4   4120     7.400616e+05
# 5   4560     7.998082e+05
# 6   5490     9.260908e+05
# 7   3460     6.504418e+05
# 8   4750     8.256079e+05
# 9   2300     4.929281e+05
# 10  9000     1.402705e+06
# 11  8600     1.348390e+06
# 12  7100     1.144709e+06

# %%
area.to_csv('Prediction.csv',index=False)

# %% [markdown]
# ### Saving Model

# %% [markdown]
# Training machine learning model can be quite time consuming if training dataset is very big. In this case it makes sense to train a model and save it to a file so that later on while making predictions, the model can be loaded from a file and need not be trained every time. Pickle and sklearn joblib modules can be used for this purpose. Joblib seems to be more efficient with big numpy arrays hence it is preferred if many numpy objects are involved in your training step.

# %%
import pickle

# %%
with open('model_pickle','wb')as f:
    pickle.dump(lr,f)

# %%
with open('model_pickle','rb') as f:
    mp = pickle.load(f)

# %%
mp.predict([[5000]])
# Out:
# array([859554.79452055])

# %%
import joblib

# %%
joblib.dump(lr,'model_joblib')
# Out:
# ['model_joblib']

# %%
mj = joblib.load('model_joblib')

# %%
mj.predict([[5000]])
# Out:
# array([859554.79452055])
