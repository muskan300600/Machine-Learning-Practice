# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('HR_comma_sep.csv')

# %%
data
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
data.head(10)
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
# 5                0.41             0.50               2                   153
# 6                0.10             0.77               6                   247
# 7                0.92             0.85               5                   259
# 8                0.89             1.00               5                   224
# 9                0.42             0.53               2                   142
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# ...

# %%
data.corr()
# Out:
#                        satisfaction_level  last_evaluation  number_project  \
# satisfaction_level               1.000000         0.105021       -0.142970
# last_evaluation                  0.105021         1.000000        0.349333
# number_project                  -0.142970         0.349333        1.000000
# average_montly_hours            -0.020048         0.339742        0.417211
# time_spend_company              -0.100866         0.131591        0.196786
# Work_accident                    0.058697        -0.007104       -0.004741
# left                            -0.388375         0.006567        0.023787
# promotion_last_5years            0.025605        -0.008684       -0.006064
#
#                        average_montly_hours  time_spend_company  \
# satisfaction_level                -0.020048           -0.100866
# last_evaluation                    0.339742            0.131591
# number_project                     0.417211            0.196786
# ...

# %%
data.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# ...

# %%
data.left.value_counts()
# Out:
# 0    11428
# 1     3571
# Name: left, dtype: int64

# %%
data.number_project.value_counts()
# Out:
# 4    4365
# 3    4055
# 5    2761
# 2    2388
# 6    1174
# 7     256
# Name: number_project, dtype: int64

# %%
data.Work_accident.value_counts()
# Out:
# 0    12830
# 1     2169
# Name: Work_accident, dtype: int64

# %%
data.promotion_last_5years.value_counts()
# Out:
# 0    14680
# 1      319
# Name: promotion_last_5years, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=data.salary,y=data.left)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='left'>

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=data.left,y=data.promotion_last_5years)
# Out:
# <AxesSubplot:xlabel='left', ylabel='promotion_last_5years'>

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=data.left,y=data.Work_accident)
# Out:
# <AxesSubplot:xlabel='left', ylabel='Work_accident'>

# %%
pd.crosstab(data.Department,data.left).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Department'>

# %%
pd.crosstab(data.satisfaction_level,data.left).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='satisfaction_level'>

# %% [markdown]
# Employess with low satisfaction level have clearly left the company.

# %%
pd.crosstab(data.average_montly_hours,data.left).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='average_montly_hours'>

# %% [markdown]
# Average Monthly hours doesn't provide a clear insight on whether or not it is related with employees leaving the company

# %%
pd.crosstab(data.number_project,data.left).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='number_project'>

# %%
pd.crosstab(data.last_evaluation,data.left).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='last_evaluation'>

# %%
pd.crosstab(data.time_spend_company,data.left).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='time_spend_company'>

# %% [markdown]
# On the basis of above visualisations, the independent variables for our model are:
# 1. Salary
# 2. Work accident
# 3. Promotion in the last 5 years
# 4. Satisfaction level

# %%
data
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
salary = pd.get_dummies(data.salary)

# %%
salary
# Out:
#        high  low  medium
# 0         0    1       0
# 1         0    0       1
# 2         0    0       1
# 3         0    1       0
# 4         0    1       0
# ...     ...  ...     ...
# 14994     0    1       0
# 14995     0    1       0
# 14996     0    1       0
# 14997     0    1       0
# 14998     0    1       0
#
# [14999 rows x 3 columns]

# %%
data = pd.concat([data,salary],axis=1)

# %%
data
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
X = data[['satisfaction_level','Work_accident','promotion_last_5years','low','medium','high']]

# %%
X
# Out:
#        satisfaction_level  Work_accident  promotion_last_5years  low  medium  \
# 0                    0.38              0                      0    1       0
# 1                    0.80              0                      0    0       1
# 2                    0.11              0                      0    0       1
# 3                    0.72              0                      0    1       0
# 4                    0.37              0                      0    1       0
# ...                   ...            ...                    ...  ...     ...
# 14994                0.40              0                      0    1       0
# 14995                0.37              0                      0    1       0
# 14996                0.37              0                      0    1       0
# 14997                0.11              0                      0    1       0
# 14998                0.37              0                      0    1       0
#
#        high
# 0         0
# 1         0
# ...

# %%
y = data.left

# %%
y
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 14994    1
# 14995    1
# 14996    1
# 14997    1
# 14998    1
# Name: left, Length: 14999, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train , X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=20)

# %%
X_train
# Out:
#        satisfaction_level  Work_accident  promotion_last_5years  low  medium  \
# 2920                 0.99              1                      0    1       0
# 10469                0.34              0                      0    0       1
# 5580                 0.88              0                      0    0       1
# 13571                0.62              0                      0    0       1
# 10147                0.55              0                      0    0       1
# ...                   ...            ...                    ...  ...     ...
# 14729                0.44              0                      0    1       0
# 7068                 0.32              1                      0    0       0
# 7391                 0.65              0                      0    1       0
# 4367                 0.83              1                      0    1       0
# 10714                0.14              1                      0    0       1
#
#        high
# 2920      0
# 10469     0
# ...

# %%
y_train
# Out:
# 2920     0
# 10469    0
# 5580     0
# 13571    0
# 10147    0
#         ..
# 14729    1
# 7068     0
# 7391     0
# 4367     0
# 10714    0
# Name: left, Length: 10499, dtype: int64

# %%
X_test
# Out:
#        satisfaction_level  Work_accident  promotion_last_5years  low  medium  \
# 6493                 0.77              0                      0    0       0
# 3568                 0.96              0                      0    0       1
# 972                  0.11              0                      0    0       1
# 3260                 0.58              0                      0    0       1
# 671                  0.11              0                      0    1       0
# ...                   ...            ...                    ...  ...     ...
# 9743                 0.50              0                      0    0       0
# 5869                 0.72              0                      0    0       1
# 14232                0.38              0                      0    1       0
# 7509                 0.39              1                      0    1       0
# 9132                 0.91              0                      0    1       0
#
#        high
# 6493      1
# 3568      0
# ...

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.predict(X_test)
# Out:
# array([0, 0, 1, ..., 0, 0, 0], dtype=int64)

# %%
lr.score(X_test,y_test)
# Out:
# 0.7893333333333333
